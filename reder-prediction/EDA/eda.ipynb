# %%
import pandas as pd

# import cleaned csv file

file_path = '..\\DataCleaning\\cleaned_dataset.csv'

try:
    df = pd.read_csv(file_path)
    print("File loaded successfully.")
except FileNotFoundError:
    print("File not found in the specified path.")
except PermissionError:
    print("Permission denied to read the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File loaded successfully.

# %%
df.head()
# Out:
#    CustomerID  Age  Gender    Segment  NPS  ChurnLabel  TotalPurchaseValue  \
# 0        1001   31    Male  Segment B    3           1            20819.84
# 1        1002   66  Female  Segment C    6           0             3804.05
# 2        1003   36  Female  Segment B    3           0             5259.54
# 3        1004   62  Female  Segment C    1           1             6067.36
# 4        1005   68  Female  Segment C    3           0            18165.53
#
#   SubscriptionPlan  TotalLatePayments  PageViews  TimeSpentOnWebsite  \
# 0          Express                 40         49                  15
# 1              Pro                 10        100                   9
# 2        Essential                  8          1                  97
# 3            Smart                 79         25                  31
# 4            Basic                  2         77                  51
#
#    NumberOfLogins FrequencyOfInteractions  Rating
# 0              19                  Weekly       1
# 1               9                  Weekly       2
# 2              19                 Monthly       4
# 3               4                   Daily       1
# 4              12                  Weekly       3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12483 entries, 0 to 12482
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CustomerID               12483 non-null  int64
#  1   Age                      12483 non-null  int64
#  2   Gender                   12483 non-null  object
#  3   Segment                  12483 non-null  object
#  4   NPS                      12483 non-null  int64
#  5   ChurnLabel               12483 non-null  int64
#  6   TotalPurchaseValue       12483 non-null  float64
#  7   SubscriptionPlan         12483 non-null  object
#  8   TotalLatePayments        12483 non-null  int64
#  9   PageViews                12483 non-null  int64
#  10  TimeSpentOnWebsite       12483 non-null  int64
#  11  NumberOfLogins           12483 non-null  int64
#  12  FrequencyOfInteractions  12483 non-null  object
#  13  Rating                   12483 non-null  int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#         CustomerID           Age           NPS    ChurnLabel  \
# count  12483.00000  12483.000000  12483.000000  12483.000000
# mean    7242.00000     43.930065      2.973884      0.505808
# std     3603.67604     15.341521      2.644623      0.499986
# min     1001.00000     18.000000      0.000000      0.000000
# 25%     4121.50000     31.000000      1.000000      0.000000
# 50%     7242.00000     44.000000      2.000000      1.000000
# 75%    10362.50000     57.000000      4.000000      1.000000
# max    13483.00000     70.000000      9.000000      1.000000
#
#        TotalPurchaseValue  TotalLatePayments     PageViews  \
# count        12483.000000       12483.000000  12483.000000
# mean         15234.481085          36.166547     50.634944
# std           9669.797190          31.411403     28.930760
# min             28.510000           0.000000      1.000000
# 25%           7288.955000           8.000000     26.000000
# 50%          14307.630000          23.000000     51.000000
# 75%          21977.720000          65.000000     76.000000
# max          50868.170000         117.000000    100.000000
#
#        TimeSpentOnWebsite  NumberOfLogins        Rating
# count        12483.000000    12483.000000  12483.000000
# mean            34.602499       15.561484      3.000641
# std             27.603618        8.694091      1.411094
# min              1.000000        1.000000      1.000000
# 25%             14.000000        8.000000      2.000000
# 50%             26.000000       16.000000      3.000000
# 75%             51.000000       23.000000      4.000000
# max            103.000000       30.000000      5.000000

# %% [markdown]
# The insights we gain from the summary statistics above are:
# 1. Age: The mean age (43.93) is less than the median age (44) meaning that age is left-skewed.
#         The minimum age is 18 years old and the maximum age is 70 years old.
#         The standard deviation is 15.34 which is relatively low meaning that most customers are aged close to the mean age of 43.93.
#         This shows that most customers are middle aged.
# 2. Total Purchase Value: The mean (15234.48) is significantly greater than the median (14307.63), meaning that the Total Purchase value is right-skewed.
#                         The standard deviation (9669.80) is significantly high meaning that most customers total purchase value differ from the mean which suggests that there is possibility of outliers.
#                         The minimum total purchase value is 28.51 and the maximum is 50868.17. This is a significantly large range which empasises that there is possibility of outliers and suggest that there are some customers who have made very few purchases.
# 3. TotalLatePayments: The mean (36.16) is significantly higher than the median (23), which suggests that TotalLatePayments in the dataset is right skewed.
#                     The standard deviation (31.41) is significantly high meaning that the total late payments of most customers differ from the mean (36)
#                     The mimimum TotalLatePayments is 0 while the maximum is 65. A significant range but suggests that there is possibility of some customers who are never late with payments.
# 4. PageViews: The mean (50) is slightly lower than the median (51) which suggests that it is left-skewed.
#                 The standard deviation (28.93) is relatively high meaning that most customers PageViews differ from the mean. There is possibility of a median mix of high and low page views.
#                 The minimum number of PageViews is 1 and the maximum is 100. This is a significantly large range meaning that there is possibility of outliers and low engagement of some customers.
# 5. TimeSpentOnWebsite: The mean is 34.60 and the median is 26 meaning that the time spent on the website is right skewed.
# The standard deviation (27.60) is significantly high meaning that Time Spent on the website by most of the customers differ from the mean.
# The minimum time spent on the website is 1 minute while the maximum time spent is 103 minutes. This suggest possibility of outliers or low  engagement by some customers.
#
# 6. Number of Logins:
#     - The mean (15.56) is slightly lower than the median (16) meaning that the number of logins is left-skewed.
#     - The standard deviation is moderately high meaning that most customers number of logins differ from the mean.
#     - The minimum number of number of logins is 1 and the maximum is 30 which suggests possibility of low engagement by some customers.
#
# 8. Rating:
#         - The mean (3) is the same as the median (3). Given a scale of 5 this suggest a moderate rating which suggests that there's need for some improvement in the products sold.
#         - The standard deviation (1.41) is low which suggests that most rating by the customers is close to the mean.
#         - The minimum rating (1) and the maximum is 5. This suggests that there is possibility of low performing products which suggests a need for improvement.

# %%
# Plot Histograms for continuous variables

import matplotlib.pyplot as plt
import seaborn as sns

plt.rc("font", size=16)
plt.rc("axes", labelsize=14, titlesize=16)
plt.rc("legend", fontsize=16)
plt.rc("xtick", labelsize=12)
plt.rc("ytick", labelsize=12)

df.hist(bins=50, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Customer Spending Distribution

# %%
# Aggregate total spend per customer
customer_spend = df.groupby("CustomerID")["TotalPurchaseValue"].sum()

# Visualization: Customer Spending Distribution
plt.figure(figsize=(10,5))
sns.histplot(customer_spend, bins=50, kde=True)
plt.title("Customer Spending Distribution")
plt.xlabel("Total Spend per Customer (£)")
plt.ylabel("Customer Count")
plt.xlim(0, customer_spend.quantile(0.99))  # Remove extreme outliers
plt.show()

# %% [markdown]
# The key insights we gain from the customer spending distribution are:
#     - The distribution is right skewed, with most customers spending between $0 and $15000
#     - There is quite a significant amount of high spenders (>35000)
#     - This suggests that there is a potential for growth. The presense of high spenders indicates the potential for increasing the average spending by implementing strategies to move low spenders to mid-value spending.

# %%
# Plot Boxplot for Age Variable
ax = df.boxplot(column='Age')
plt.title('Box Plot of Ages')
plt.show()

# %%
# Plot Boxplot for Age Variable
ax = df.boxplot(column='NPS')
plt.title('Box Plot of NPS')
plt.show()

# %% [markdown]
# The insight we gain from the NPS box plot is that there is a single outlier above 8
# The IQR is 3 and the median is 2

# %%
# Plot Boxplot for TotalPurchaseValue Variable
ax = df.boxplot(column='TotalPurchaseValue')
plt.title('Box Plot of TotalPurchaseValue')
plt.show()

# %% [markdown]
# The insights we gauge from hte TotalPurchase Value box plot is that there is a significant amount of outliers which are above 44000. For this dataset I will not do away with these outliers to avoid skewing the data.

# %%
# Plot Boxplot for TotalLatePayments Variable
ax = df.boxplot(column='TotalLatePayments')
plt.title('Box Plot of TotalLatePayments')
plt.show()

# %%
# Plot Boxplot for PageViews Variable
ax = df.boxplot(column='PageViews')
plt.title('Box Plot of PageViews')
plt.show()

# %%
# Plot Boxplot for TimeSpentOnWebsite Variable
ax = df.boxplot(column='TimeSpentOnWebsite')
plt.title('Box Plot of TimeSpentOnWebsite')
plt.show()

# %%
# Plot Boxplot for NumberOfLogins Variable
ax = df.boxplot(column='NumberOfLogins')
plt.title('Box Plot of NumberOfLogins')
plt.show()

# %%
# Plot Boxplot for Rating Variable
ax = df.boxplot(column='Rating')
plt.title('Box Plot of Rating')
plt.show()

# %%
# Group by Segment and sum the TotalPurchaseValue
segment_sums = df.groupby('Segment')['TotalPurchaseValue'].sum()

# Plot a pie chart of TotalPurchaseValue against Segment
# Add totals to labels
labels = [f"{seg} (${val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Total Purchase Value by Segment')
plt.show()

# %% [markdown]
# The key insight we gain from the Distribution of Total Purchase Value by Segment:
#     - The total purchase value by segment is significantly almost similar. Meaning that there is no dominant segment.

# %%
# Group by Gender and sum the TotalPurchaseValue
segment_sums = df.groupby('Gender')['TotalPurchaseValue'].sum()

# Plot a pie chart of TotalPurchaseValue against Segment
# Add totals to labels
labels = [f"{seg} (${val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Total Purchase Value by Gender')
plt.show()

# %% [markdown]
# The key insight we gain from the Distribution of Total Purchase Value by Gender is that:
#     - The total purchase value is slightly dominated by males (50.4) as compared to females (49.6).

# %%
# Group by SubscriptionPlan and sum the TotalPurchaseValue
segment_sums = df.groupby('SubscriptionPlan')['TotalPurchaseValue'].sum()

# Bar plot of TotalPurchaseValue by SubscriptionPlan
plt.figure(figsize=(10, 6))
plt.bar(segment_sums.index, segment_sums.values, color='skyblue')

plt.title('Total Purchase Value by Subscription Plan')
plt.xlabel('Subscription Plan')
plt.ylabel('Total Purchase Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the Total Purchase Value by Sibscription Plan bar plot the key insights we gain are that:
#     - The highest total purchase value is from students.
#     - The lowest is the Elite

# %%
# Group by Gender and sum the TimeSpentOnWebsite
segment_sums = df.groupby('Gender')['TimeSpentOnWebsite'].sum()

# Plot a pie chart of TimeSpentOnWebsite against Gender
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TimeSpentOnWebsite by Gender')
plt.show()

# %% [markdown]
# The key insight we gain from this is that there is the possibility that Females spend more time on the website as compared to males which is slightly higher.

# %%
# Group by Segment and sum the TimeSpentOnWebsite
segment_sums = df.groupby('Segment')['TimeSpentOnWebsite'].sum()

# Plot a pie chart of TimeSpentOnWebsite against Segment
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TimeSpentOnWebsite by Segment')
plt.show()

# %%
# Group by Gender and sum the TotalLatePayments
segment_sums = df.groupby('Gender')['TotalLatePayments'].sum()

# Plot a pie chart of TotalLatePayments against Gender
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TotalLatePayments by Gender')
plt.show()

# %%
# Group by Segment and sum the TotalLatePayments
segment_sums = df.groupby('Segment')['TotalLatePayments'].sum()

# Plot a pie chart of TotalLatePayments against Segment
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TotalLatePayments by Segment')
plt.show()

# %% [markdown]
# The key insight we gain from this is that there is the possibility that Males have the most late payments as compared to Females.

# %%
# Group by Gender and sum the PageViews
segment_sums = df.groupby('Gender')['PageViews'].sum()

# Plot a pie chart of TotalPageViews against Gender
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TotalPageViews by Gender')
plt.show()

# %% [markdown]
# The key insight we gain from this is that there is the possibility that Males have the most page views as compared to Females.

# %%
# Group by Segment and sum the PageViews
segment_sums = df.groupby('Segment')['PageViews'].sum()

# Plot a pie chart of TotalPageViews against Segment
# Add totals to labels
labels = [f"{seg} ({val:,.0f})" for seg, val in segment_sums.items()]

plt.figure(figsize=(8, 8))
plt.pie(segment_sums, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of TotalPageViews by Segment')
plt.show()
